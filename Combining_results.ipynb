# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('results.csv')

# %%
df.loc[df['Publishable'] == 0, ['Conference', 'Rationale']] = 'na'
df.head()
# Out:
#   Paper ID  Publishable Conference  \
# 0     P001            1       CVPR
# 1     P002            0         na
# 2     P003            1       TMLR
# 3     P004            1        KDD
# 4     P005            1    NeurIPS
#
#                                            Rationale
# 0  The paper's topic overlaps moderately with CVP...
# 1                                                 na
# 2  The paper's topic overlaps moderately with TML...
# 3  The paper's topic overlaps moderately with KDD...
# 4  The paper aligns well with NeurIPS, focusing o...

# %%
df['Conference'] = df['Conference'].str.lower()

# %%
from google.colab import files
df.to_csv('results.csv', index=False)
files.download('results.csv')
